# %%
import numpy as np
# Surgery type attributes (previously defined)
surgery_type_attributes = {
    "Cardiovascular": {"duration": 4, "variance": 1.0, "priority": 5},
    "Neurological": {"duration": 2, "variance": 1.2, "priority": 4},
    "Orthopedic": {"duration": 3, "variance": 0.5, "priority": 3},
    "Gastrointestinal": {"duration": 4, "variance": 0.7, "priority": 2},
    "Cosmetic": {"duration": 5, "variance": 0.3, "priority": 1},
}

total_surgeries_of_each_type = {1: 9000, 2: 1, 3: 1, 4: 1, 5: 1}

type_names = {
    1: "Cardiovascular",
    2: "Neurological",
    3: "Orthopedic",
    4: "Gastrointestinal",
    5: "Cosmetic",
}

# Generate the surgeries list based on the new structure
surgeries = [
    f"{type_names[type_id]} Surgery {i}"
    for type_id, count in total_surgeries_of_each_type.items()
    for i in range(1, count + 1)
]

# Extend surgeries list to include an intake_date
extended_surgeries = [
    {
        "id": f"{type_names[type_id]}_Surgery_{i}_Intake_{np.random.randint(1, 11)}",  # Unique identifier
        "name": f"{type_names[type_id]} Surgery {i}",
        "type_id": type_id,
        "intake_date": np.random.randint(1, 11)  # Random intake date between 1 and 10
    }
    for type_id, count in total_surgeries_of_each_type.items()
    for i in range(1, count + 1)
]

# %%
extended_surgeries
# Out:
# [{'id': 'Cardiovascular_Surgery_1_Intake_4',
#   'name': 'Cardiovascular Surgery 1',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_2_Intake_1',
#   'name': 'Cardiovascular Surgery 2',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_3_Intake_3',
#   'name': 'Cardiovascular Surgery 3',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_4_Intake_4',
#   'name': 'Cardiovascular Surgery 4',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_5_Intake_1',
#   'name': 'Cardiovascular Surgery 5',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_6_Intake_6',
#   'name': 'Cardiovascular Surgery 6',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_7_Intake_4',
#   'name': 'Cardiovascular Surgery 7',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_8_Intake_8',
#   'name': 'Cardiovascular Surgery 8',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_9_Intake_6',
#   'name': 'Cardiovascular Surgery 9',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_10_Intake_6',
#   'name': 'Cardiovascular Surgery 10',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_11_Intake_10',
#   'name': 'Cardiovascular Surgery 11',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_12_Intake_7',
#   'name': 'Cardiovascular Surgery 12',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_13_Intake_1',
#   'name': 'Cardiovascular Surgery 13',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_14_Intake_7',
#   'name': 'Cardiovascular Surgery 14',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_15_Intake_5',
#   'name': 'Cardiovascular Surgery 15',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_16_Intake_4',
#   'name': 'Cardiovascular Surgery 16',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_17_Intake_4',
#   'name': 'Cardiovascular Surgery 17',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_18_Intake_8',
#   'name': 'Cardiovascular Surgery 18',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_19_Intake_5',
#   'name': 'Cardiovascular Surgery 19',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_20_Intake_8',
#   'name': 'Cardiovascular Surgery 20',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_21_Intake_7',
#   'name': 'Cardiovascular Surgery 21',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_22_Intake_5',
#   'name': 'Cardiovascular Surgery 22',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_23_Intake_9',
#   'name': 'Cardiovascular Surgery 23',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_24_Intake_3',
#   'name': 'Cardiovascular Surgery 24',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_25_Intake_8',
#   'name': 'Cardiovascular Surgery 25',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_26_Intake_8',
#   'name': 'Cardiovascular Surgery 26',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_27_Intake_7',
#   'name': 'Cardiovascular Surgery 27',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_28_Intake_2',
#   'name': 'Cardiovascular Surgery 28',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_29_Intake_3',
#   'name': 'Cardiovascular Surgery 29',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_30_Intake_8',
#   'name': 'Cardiovascular Surgery 30',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_31_Intake_1',
#   'name': 'Cardiovascular Surgery 31',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_32_Intake_5',
#   'name': 'Cardiovascular Surgery 32',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_33_Intake_10',
#   'name': 'Cardiovascular Surgery 33',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_34_Intake_10',
#   'name': 'Cardiovascular Surgery 34',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_35_Intake_1',
#   'name': 'Cardiovascular Surgery 35',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_36_Intake_5',
#   'name': 'Cardiovascular Surgery 36',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_37_Intake_1',
#   'name': 'Cardiovascular Surgery 37',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_38_Intake_6',
#   'name': 'Cardiovascular Surgery 38',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_39_Intake_3',
#   'name': 'Cardiovascular Surgery 39',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_40_Intake_1',
#   'name': 'Cardiovascular Surgery 40',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_41_Intake_2',
#   'name': 'Cardiovascular Surgery 41',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_42_Intake_7',
#   'name': 'Cardiovascular Surgery 42',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_43_Intake_4',
#   'name': 'Cardiovascular Surgery 43',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_44_Intake_6',
#   'name': 'Cardiovascular Surgery 44',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_45_Intake_2',
#   'name': 'Cardiovascular Surgery 45',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_46_Intake_4',
#   'name': 'Cardiovascular Surgery 46',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_47_Intake_2',
#   'name': 'Cardiovascular Surgery 47',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_48_Intake_2',
#   'name': 'Cardiovascular Surgery 48',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_49_Intake_10',
#   'name': 'Cardiovascular Surgery 49',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_50_Intake_1',
#   'name': 'Cardiovascular Surgery 50',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_51_Intake_10',
#   'name': 'Cardiovascular Surgery 51',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_52_Intake_1',
#   'name': 'Cardiovascular Surgery 52',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_53_Intake_2',
#   'name': 'Cardiovascular Surgery 53',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_54_Intake_2',
#   'name': 'Cardiovascular Surgery 54',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_55_Intake_10',
#   'name': 'Cardiovascular Surgery 55',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_56_Intake_2',
#   'name': 'Cardiovascular Surgery 56',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_57_Intake_8',
#   'name': 'Cardiovascular Surgery 57',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_58_Intake_6',
#   'name': 'Cardiovascular Surgery 58',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_59_Intake_1',
#   'name': 'Cardiovascular Surgery 59',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_60_Intake_9',
#   'name': 'Cardiovascular Surgery 60',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_61_Intake_3',
#   'name': 'Cardiovascular Surgery 61',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_62_Intake_8',
#   'name': 'Cardiovascular Surgery 62',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_63_Intake_2',
#   'name': 'Cardiovascular Surgery 63',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_64_Intake_6',
#   'name': 'Cardiovascular Surgery 64',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_65_Intake_5',
#   'name': 'Cardiovascular Surgery 65',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_66_Intake_1',
#   'name': 'Cardiovascular Surgery 66',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_67_Intake_1',
#   'name': 'Cardiovascular Surgery 67',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_68_Intake_2',
#   'name': 'Cardiovascular Surgery 68',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_69_Intake_8',
#   'name': 'Cardiovascular Surgery 69',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_70_Intake_2',
#   'name': 'Cardiovascular Surgery 70',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_71_Intake_9',
#   'name': 'Cardiovascular Surgery 71',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_72_Intake_3',
#   'name': 'Cardiovascular Surgery 72',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_73_Intake_8',
#   'name': 'Cardiovascular Surgery 73',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_74_Intake_1',
#   'name': 'Cardiovascular Surgery 74',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_75_Intake_3',
#   'name': 'Cardiovascular Surgery 75',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_76_Intake_5',
#   'name': 'Cardiovascular Surgery 76',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_77_Intake_1',
#   'name': 'Cardiovascular Surgery 77',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_78_Intake_10',
#   'name': 'Cardiovascular Surgery 78',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_79_Intake_4',
#   'name': 'Cardiovascular Surgery 79',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_80_Intake_2',
#   'name': 'Cardiovascular Surgery 80',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_81_Intake_9',
#   'name': 'Cardiovascular Surgery 81',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_82_Intake_7',
#   'name': 'Cardiovascular Surgery 82',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_83_Intake_10',
#   'name': 'Cardiovascular Surgery 83',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_84_Intake_3',
#   'name': 'Cardiovascular Surgery 84',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_85_Intake_5',
#   'name': 'Cardiovascular Surgery 85',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_86_Intake_2',
#   'name': 'Cardiovascular Surgery 86',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_87_Intake_1',
#   'name': 'Cardiovascular Surgery 87',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_88_Intake_5',
#   'name': 'Cardiovascular Surgery 88',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_89_Intake_6',
#   'name': 'Cardiovascular Surgery 89',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_90_Intake_1',
#   'name': 'Cardiovascular Surgery 90',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_91_Intake_1',
#   'name': 'Cardiovascular Surgery 91',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_92_Intake_8',
#   'name': 'Cardiovascular Surgery 92',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_93_Intake_1',
#   'name': 'Cardiovascular Surgery 93',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_94_Intake_1',
#   'name': 'Cardiovascular Surgery 94',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_95_Intake_5',
#   'name': 'Cardiovascular Surgery 95',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_96_Intake_10',
#   'name': 'Cardiovascular Surgery 96',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_97_Intake_7',
#   'name': 'Cardiovascular Surgery 97',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_98_Intake_10',
#   'name': 'Cardiovascular Surgery 98',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_99_Intake_5',
#   'name': 'Cardiovascular Surgery 99',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_100_Intake_5',
#   'name': 'Cardiovascular Surgery 100',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_101_Intake_3',
#   'name': 'Cardiovascular Surgery 101',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_102_Intake_4',
#   'name': 'Cardiovascular Surgery 102',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_103_Intake_4',
#   'name': 'Cardiovascular Surgery 103',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_104_Intake_3',
#   'name': 'Cardiovascular Surgery 104',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_105_Intake_3',
#   'name': 'Cardiovascular Surgery 105',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_106_Intake_9',
#   'name': 'Cardiovascular Surgery 106',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_107_Intake_8',
#   'name': 'Cardiovascular Surgery 107',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_108_Intake_9',
#   'name': 'Cardiovascular Surgery 108',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_109_Intake_10',
#   'name': 'Cardiovascular Surgery 109',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_110_Intake_6',
#   'name': 'Cardiovascular Surgery 110',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_111_Intake_3',
#   'name': 'Cardiovascular Surgery 111',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_112_Intake_2',
#   'name': 'Cardiovascular Surgery 112',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_113_Intake_6',
#   'name': 'Cardiovascular Surgery 113',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_114_Intake_2',
#   'name': 'Cardiovascular Surgery 114',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_115_Intake_10',
#   'name': 'Cardiovascular Surgery 115',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_116_Intake_1',
#   'name': 'Cardiovascular Surgery 116',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_117_Intake_10',
#   'name': 'Cardiovascular Surgery 117',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_118_Intake_9',
#   'name': 'Cardiovascular Surgery 118',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_119_Intake_5',
#   'name': 'Cardiovascular Surgery 119',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_120_Intake_4',
#   'name': 'Cardiovascular Surgery 120',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_121_Intake_1',
#   'name': 'Cardiovascular Surgery 121',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_122_Intake_6',
#   'name': 'Cardiovascular Surgery 122',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_123_Intake_1',
#   'name': 'Cardiovascular Surgery 123',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_124_Intake_1',
#   'name': 'Cardiovascular Surgery 124',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_125_Intake_3',
#   'name': 'Cardiovascular Surgery 125',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_126_Intake_2',
#   'name': 'Cardiovascular Surgery 126',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_127_Intake_3',
#   'name': 'Cardiovascular Surgery 127',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_128_Intake_7',
#   'name': 'Cardiovascular Surgery 128',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_129_Intake_2',
#   'name': 'Cardiovascular Surgery 129',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_130_Intake_6',
#   'name': 'Cardiovascular Surgery 130',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_131_Intake_10',
#   'name': 'Cardiovascular Surgery 131',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_132_Intake_6',
#   'name': 'Cardiovascular Surgery 132',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_133_Intake_7',
#   'name': 'Cardiovascular Surgery 133',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_134_Intake_2',
#   'name': 'Cardiovascular Surgery 134',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_135_Intake_8',
#   'name': 'Cardiovascular Surgery 135',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_136_Intake_4',
#   'name': 'Cardiovascular Surgery 136',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_137_Intake_4',
#   'name': 'Cardiovascular Surgery 137',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_138_Intake_4',
#   'name': 'Cardiovascular Surgery 138',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_139_Intake_3',
#   'name': 'Cardiovascular Surgery 139',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_140_Intake_3',
#   'name': 'Cardiovascular Surgery 140',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_141_Intake_7',
#   'name': 'Cardiovascular Surgery 141',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_142_Intake_1',
#   'name': 'Cardiovascular Surgery 142',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_143_Intake_2',
#   'name': 'Cardiovascular Surgery 143',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_144_Intake_8',
#   'name': 'Cardiovascular Surgery 144',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_145_Intake_4',
#   'name': 'Cardiovascular Surgery 145',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_146_Intake_10',
#   'name': 'Cardiovascular Surgery 146',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_147_Intake_3',
#   'name': 'Cardiovascular Surgery 147',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_148_Intake_10',
#   'name': 'Cardiovascular Surgery 148',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_149_Intake_3',
#   'name': 'Cardiovascular Surgery 149',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_150_Intake_10',
#   'name': 'Cardiovascular Surgery 150',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_151_Intake_3',
#   'name': 'Cardiovascular Surgery 151',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_152_Intake_10',
#   'name': 'Cardiovascular Surgery 152',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_153_Intake_5',
#   'name': 'Cardiovascular Surgery 153',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_154_Intake_6',
#   'name': 'Cardiovascular Surgery 154',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_155_Intake_5',
#   'name': 'Cardiovascular Surgery 155',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_156_Intake_9',
#   'name': 'Cardiovascular Surgery 156',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_157_Intake_8',
#   'name': 'Cardiovascular Surgery 157',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_158_Intake_8',
#   'name': 'Cardiovascular Surgery 158',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_159_Intake_3',
#   'name': 'Cardiovascular Surgery 159',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_160_Intake_2',
#   'name': 'Cardiovascular Surgery 160',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_161_Intake_4',
#   'name': 'Cardiovascular Surgery 161',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_162_Intake_7',
#   'name': 'Cardiovascular Surgery 162',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_163_Intake_4',
#   'name': 'Cardiovascular Surgery 163',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_164_Intake_6',
#   'name': 'Cardiovascular Surgery 164',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_165_Intake_9',
#   'name': 'Cardiovascular Surgery 165',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_166_Intake_3',
#   'name': 'Cardiovascular Surgery 166',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_167_Intake_1',
#   'name': 'Cardiovascular Surgery 167',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_168_Intake_6',
#   'name': 'Cardiovascular Surgery 168',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_169_Intake_1',
#   'name': 'Cardiovascular Surgery 169',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_170_Intake_3',
#   'name': 'Cardiovascular Surgery 170',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_171_Intake_5',
#   'name': 'Cardiovascular Surgery 171',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_172_Intake_2',
#   'name': 'Cardiovascular Surgery 172',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_173_Intake_10',
#   'name': 'Cardiovascular Surgery 173',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_174_Intake_6',
#   'name': 'Cardiovascular Surgery 174',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_175_Intake_8',
#   'name': 'Cardiovascular Surgery 175',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_176_Intake_9',
#   'name': 'Cardiovascular Surgery 176',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_177_Intake_6',
#   'name': 'Cardiovascular Surgery 177',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_178_Intake_6',
#   'name': 'Cardiovascular Surgery 178',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_179_Intake_4',
#   'name': 'Cardiovascular Surgery 179',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_180_Intake_3',
#   'name': 'Cardiovascular Surgery 180',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_181_Intake_4',
#   'name': 'Cardiovascular Surgery 181',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_182_Intake_9',
#   'name': 'Cardiovascular Surgery 182',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_183_Intake_1',
#   'name': 'Cardiovascular Surgery 183',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_184_Intake_4',
#   'name': 'Cardiovascular Surgery 184',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_185_Intake_2',
#   'name': 'Cardiovascular Surgery 185',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_186_Intake_4',
#   'name': 'Cardiovascular Surgery 186',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_187_Intake_8',
#   'name': 'Cardiovascular Surgery 187',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_188_Intake_2',
#   'name': 'Cardiovascular Surgery 188',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_189_Intake_1',
#   'name': 'Cardiovascular Surgery 189',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_190_Intake_6',
#   'name': 'Cardiovascular Surgery 190',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_191_Intake_9',
#   'name': 'Cardiovascular Surgery 191',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_192_Intake_7',
#   'name': 'Cardiovascular Surgery 192',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_193_Intake_1',
#   'name': 'Cardiovascular Surgery 193',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_194_Intake_10',
#   'name': 'Cardiovascular Surgery 194',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_195_Intake_1',
#   'name': 'Cardiovascular Surgery 195',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_196_Intake_10',
#   'name': 'Cardiovascular Surgery 196',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_197_Intake_8',
#   'name': 'Cardiovascular Surgery 197',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_198_Intake_3',
#   'name': 'Cardiovascular Surgery 198',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_199_Intake_4',
#   'name': 'Cardiovascular Surgery 199',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_200_Intake_8',
#   'name': 'Cardiovascular Surgery 200',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_201_Intake_3',
#   'name': 'Cardiovascular Surgery 201',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_202_Intake_1',
#   'name': 'Cardiovascular Surgery 202',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_203_Intake_5',
#   'name': 'Cardiovascular Surgery 203',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_204_Intake_5',
#   'name': 'Cardiovascular Surgery 204',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_205_Intake_10',
#   'name': 'Cardiovascular Surgery 205',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_206_Intake_5',
#   'name': 'Cardiovascular Surgery 206',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_207_Intake_5',
#   'name': 'Cardiovascular Surgery 207',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_208_Intake_1',
#   'name': 'Cardiovascular Surgery 208',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_209_Intake_9',
#   'name': 'Cardiovascular Surgery 209',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_210_Intake_1',
#   'name': 'Cardiovascular Surgery 210',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_211_Intake_9',
#   'name': 'Cardiovascular Surgery 211',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_212_Intake_4',
#   'name': 'Cardiovascular Surgery 212',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_213_Intake_1',
#   'name': 'Cardiovascular Surgery 213',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_214_Intake_9',
#   'name': 'Cardiovascular Surgery 214',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_215_Intake_6',
#   'name': 'Cardiovascular Surgery 215',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_216_Intake_9',
#   'name': 'Cardiovascular Surgery 216',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_217_Intake_4',
#   'name': 'Cardiovascular Surgery 217',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_218_Intake_9',
#   'name': 'Cardiovascular Surgery 218',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_219_Intake_3',
#   'name': 'Cardiovascular Surgery 219',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_220_Intake_10',
#   'name': 'Cardiovascular Surgery 220',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_221_Intake_1',
#   'name': 'Cardiovascular Surgery 221',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_222_Intake_3',
#   'name': 'Cardiovascular Surgery 222',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_223_Intake_6',
#   'name': 'Cardiovascular Surgery 223',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_224_Intake_8',
#   'name': 'Cardiovascular Surgery 224',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_225_Intake_5',
#   'name': 'Cardiovascular Surgery 225',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_226_Intake_3',
#   'name': 'Cardiovascular Surgery 226',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_227_Intake_3',
#   'name': 'Cardiovascular Surgery 227',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_228_Intake_7',
#   'name': 'Cardiovascular Surgery 228',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_229_Intake_4',
#   'name': 'Cardiovascular Surgery 229',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_230_Intake_5',
#   'name': 'Cardiovascular Surgery 230',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_231_Intake_1',
#   'name': 'Cardiovascular Surgery 231',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_232_Intake_7',
#   'name': 'Cardiovascular Surgery 232',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_233_Intake_6',
#   'name': 'Cardiovascular Surgery 233',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_234_Intake_4',
#   'name': 'Cardiovascular Surgery 234',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_235_Intake_2',
#   'name': 'Cardiovascular Surgery 235',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_236_Intake_3',
#   'name': 'Cardiovascular Surgery 236',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_237_Intake_2',
#   'name': 'Cardiovascular Surgery 237',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_238_Intake_1',
#   'name': 'Cardiovascular Surgery 238',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_239_Intake_5',
#   'name': 'Cardiovascular Surgery 239',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_240_Intake_7',
#   'name': 'Cardiovascular Surgery 240',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_241_Intake_9',
#   'name': 'Cardiovascular Surgery 241',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_242_Intake_8',
#   'name': 'Cardiovascular Surgery 242',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_243_Intake_4',
#   'name': 'Cardiovascular Surgery 243',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_244_Intake_8',
#   'name': 'Cardiovascular Surgery 244',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_245_Intake_10',
#   'name': 'Cardiovascular Surgery 245',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_246_Intake_5',
#   'name': 'Cardiovascular Surgery 246',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_247_Intake_4',
#   'name': 'Cardiovascular Surgery 247',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_248_Intake_6',
#   'name': 'Cardiovascular Surgery 248',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_249_Intake_10',
#   'name': 'Cardiovascular Surgery 249',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_250_Intake_3',
#   'name': 'Cardiovascular Surgery 250',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_251_Intake_10',
#   'name': 'Cardiovascular Surgery 251',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_252_Intake_7',
#   'name': 'Cardiovascular Surgery 252',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_253_Intake_2',
#   'name': 'Cardiovascular Surgery 253',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_254_Intake_5',
#   'name': 'Cardiovascular Surgery 254',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_255_Intake_10',
#   'name': 'Cardiovascular Surgery 255',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_256_Intake_2',
#   'name': 'Cardiovascular Surgery 256',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_257_Intake_10',
#   'name': 'Cardiovascular Surgery 257',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_258_Intake_9',
#   'name': 'Cardiovascular Surgery 258',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_259_Intake_1',
#   'name': 'Cardiovascular Surgery 259',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_260_Intake_3',
#   'name': 'Cardiovascular Surgery 260',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_261_Intake_3',
#   'name': 'Cardiovascular Surgery 261',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_262_Intake_2',
#   'name': 'Cardiovascular Surgery 262',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_263_Intake_3',
#   'name': 'Cardiovascular Surgery 263',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_264_Intake_9',
#   'name': 'Cardiovascular Surgery 264',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_265_Intake_6',
#   'name': 'Cardiovascular Surgery 265',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_266_Intake_6',
#   'name': 'Cardiovascular Surgery 266',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_267_Intake_1',
#   'name': 'Cardiovascular Surgery 267',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_268_Intake_5',
#   'name': 'Cardiovascular Surgery 268',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_269_Intake_7',
#   'name': 'Cardiovascular Surgery 269',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_270_Intake_7',
#   'name': 'Cardiovascular Surgery 270',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_271_Intake_1',
#   'name': 'Cardiovascular Surgery 271',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_272_Intake_4',
#   'name': 'Cardiovascular Surgery 272',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_273_Intake_6',
#   'name': 'Cardiovascular Surgery 273',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_274_Intake_7',
#   'name': 'Cardiovascular Surgery 274',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_275_Intake_6',
#   'name': 'Cardiovascular Surgery 275',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_276_Intake_9',
#   'name': 'Cardiovascular Surgery 276',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_277_Intake_3',
#   'name': 'Cardiovascular Surgery 277',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_278_Intake_9',
#   'name': 'Cardiovascular Surgery 278',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_279_Intake_8',
#   'name': 'Cardiovascular Surgery 279',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_280_Intake_9',
#   'name': 'Cardiovascular Surgery 280',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_281_Intake_2',
#   'name': 'Cardiovascular Surgery 281',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_282_Intake_4',
#   'name': 'Cardiovascular Surgery 282',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_283_Intake_3',
#   'name': 'Cardiovascular Surgery 283',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_284_Intake_2',
#   'name': 'Cardiovascular Surgery 284',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_285_Intake_10',
#   'name': 'Cardiovascular Surgery 285',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_286_Intake_4',
#   'name': 'Cardiovascular Surgery 286',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_287_Intake_2',
#   'name': 'Cardiovascular Surgery 287',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_288_Intake_1',
#   'name': 'Cardiovascular Surgery 288',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_289_Intake_1',
#   'name': 'Cardiovascular Surgery 289',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_290_Intake_7',
#   'name': 'Cardiovascular Surgery 290',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_291_Intake_7',
#   'name': 'Cardiovascular Surgery 291',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_292_Intake_1',
#   'name': 'Cardiovascular Surgery 292',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_293_Intake_4',
#   'name': 'Cardiovascular Surgery 293',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_294_Intake_7',
#   'name': 'Cardiovascular Surgery 294',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_295_Intake_2',
#   'name': 'Cardiovascular Surgery 295',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_296_Intake_8',
#   'name': 'Cardiovascular Surgery 296',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_297_Intake_3',
#   'name': 'Cardiovascular Surgery 297',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_298_Intake_2',
#   'name': 'Cardiovascular Surgery 298',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_299_Intake_6',
#   'name': 'Cardiovascular Surgery 299',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_300_Intake_8',
#   'name': 'Cardiovascular Surgery 300',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_301_Intake_7',
#   'name': 'Cardiovascular Surgery 301',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_302_Intake_4',
#   'name': 'Cardiovascular Surgery 302',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_303_Intake_5',
#   'name': 'Cardiovascular Surgery 303',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_304_Intake_4',
#   'name': 'Cardiovascular Surgery 304',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_305_Intake_4',
#   'name': 'Cardiovascular Surgery 305',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_306_Intake_4',
#   'name': 'Cardiovascular Surgery 306',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_307_Intake_7',
#   'name': 'Cardiovascular Surgery 307',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_308_Intake_3',
#   'name': 'Cardiovascular Surgery 308',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_309_Intake_5',
#   'name': 'Cardiovascular Surgery 309',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_310_Intake_7',
#   'name': 'Cardiovascular Surgery 310',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_311_Intake_9',
#   'name': 'Cardiovascular Surgery 311',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_312_Intake_10',
#   'name': 'Cardiovascular Surgery 312',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_313_Intake_8',
#   'name': 'Cardiovascular Surgery 313',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_314_Intake_3',
#   'name': 'Cardiovascular Surgery 314',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_315_Intake_8',
#   'name': 'Cardiovascular Surgery 315',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_316_Intake_6',
#   'name': 'Cardiovascular Surgery 316',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_317_Intake_7',
#   'name': 'Cardiovascular Surgery 317',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_318_Intake_4',
#   'name': 'Cardiovascular Surgery 318',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_319_Intake_4',
#   'name': 'Cardiovascular Surgery 319',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_320_Intake_8',
#   'name': 'Cardiovascular Surgery 320',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_321_Intake_6',
#   'name': 'Cardiovascular Surgery 321',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_322_Intake_4',
#   'name': 'Cardiovascular Surgery 322',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_323_Intake_1',
#   'name': 'Cardiovascular Surgery 323',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_324_Intake_10',
#   'name': 'Cardiovascular Surgery 324',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_325_Intake_10',
#   'name': 'Cardiovascular Surgery 325',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_326_Intake_9',
#   'name': 'Cardiovascular Surgery 326',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_327_Intake_2',
#   'name': 'Cardiovascular Surgery 327',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_328_Intake_8',
#   'name': 'Cardiovascular Surgery 328',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_329_Intake_2',
#   'name': 'Cardiovascular Surgery 329',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_330_Intake_2',
#   'name': 'Cardiovascular Surgery 330',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_331_Intake_7',
#   'name': 'Cardiovascular Surgery 331',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_332_Intake_10',
#   'name': 'Cardiovascular Surgery 332',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_333_Intake_6',
#   'name': 'Cardiovascular Surgery 333',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_334_Intake_4',
#   'name': 'Cardiovascular Surgery 334',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_335_Intake_6',
#   'name': 'Cardiovascular Surgery 335',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_336_Intake_3',
#   'name': 'Cardiovascular Surgery 336',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_337_Intake_8',
#   'name': 'Cardiovascular Surgery 337',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_338_Intake_7',
#   'name': 'Cardiovascular Surgery 338',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_339_Intake_8',
#   'name': 'Cardiovascular Surgery 339',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_340_Intake_2',
#   'name': 'Cardiovascular Surgery 340',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_341_Intake_8',
#   'name': 'Cardiovascular Surgery 341',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_342_Intake_1',
#   'name': 'Cardiovascular Surgery 342',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_343_Intake_5',
#   'name': 'Cardiovascular Surgery 343',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_344_Intake_2',
#   'name': 'Cardiovascular Surgery 344',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_345_Intake_9',
#   'name': 'Cardiovascular Surgery 345',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_346_Intake_2',
#   'name': 'Cardiovascular Surgery 346',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_347_Intake_1',
#   'name': 'Cardiovascular Surgery 347',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_348_Intake_5',
#   'name': 'Cardiovascular Surgery 348',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_349_Intake_6',
#   'name': 'Cardiovascular Surgery 349',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_350_Intake_4',
#   'name': 'Cardiovascular Surgery 350',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_351_Intake_6',
#   'name': 'Cardiovascular Surgery 351',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_352_Intake_6',
#   'name': 'Cardiovascular Surgery 352',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_353_Intake_10',
#   'name': 'Cardiovascular Surgery 353',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_354_Intake_2',
#   'name': 'Cardiovascular Surgery 354',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_355_Intake_4',
#   'name': 'Cardiovascular Surgery 355',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_356_Intake_9',
#   'name': 'Cardiovascular Surgery 356',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_357_Intake_9',
#   'name': 'Cardiovascular Surgery 357',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_358_Intake_2',
#   'name': 'Cardiovascular Surgery 358',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_359_Intake_4',
#   'name': 'Cardiovascular Surgery 359',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_360_Intake_4',
#   'name': 'Cardiovascular Surgery 360',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_361_Intake_2',
#   'name': 'Cardiovascular Surgery 361',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_362_Intake_9',
#   'name': 'Cardiovascular Surgery 362',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_363_Intake_5',
#   'name': 'Cardiovascular Surgery 363',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_364_Intake_10',
#   'name': 'Cardiovascular Surgery 364',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_365_Intake_10',
#   'name': 'Cardiovascular Surgery 365',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_366_Intake_1',
#   'name': 'Cardiovascular Surgery 366',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_367_Intake_2',
#   'name': 'Cardiovascular Surgery 367',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_368_Intake_7',
#   'name': 'Cardiovascular Surgery 368',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_369_Intake_2',
#   'name': 'Cardiovascular Surgery 369',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_370_Intake_6',
#   'name': 'Cardiovascular Surgery 370',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_371_Intake_9',
#   'name': 'Cardiovascular Surgery 371',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_372_Intake_5',
#   'name': 'Cardiovascular Surgery 372',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_373_Intake_4',
#   'name': 'Cardiovascular Surgery 373',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_374_Intake_1',
#   'name': 'Cardiovascular Surgery 374',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_375_Intake_7',
#   'name': 'Cardiovascular Surgery 375',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_376_Intake_9',
#   'name': 'Cardiovascular Surgery 376',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_377_Intake_10',
#   'name': 'Cardiovascular Surgery 377',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_378_Intake_5',
#   'name': 'Cardiovascular Surgery 378',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_379_Intake_9',
#   'name': 'Cardiovascular Surgery 379',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_380_Intake_3',
#   'name': 'Cardiovascular Surgery 380',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_381_Intake_1',
#   'name': 'Cardiovascular Surgery 381',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_382_Intake_8',
#   'name': 'Cardiovascular Surgery 382',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_383_Intake_2',
#   'name': 'Cardiovascular Surgery 383',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_384_Intake_4',
#   'name': 'Cardiovascular Surgery 384',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_385_Intake_9',
#   'name': 'Cardiovascular Surgery 385',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_386_Intake_8',
#   'name': 'Cardiovascular Surgery 386',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_387_Intake_5',
#   'name': 'Cardiovascular Surgery 387',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_388_Intake_2',
#   'name': 'Cardiovascular Surgery 388',
#   'type_id': 1,
#   'intake_date': 3},
# ...
#   'name': 'Cardiovascular Surgery 872',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_873_Intake_9',
#   'name': 'Cardiovascular Surgery 873',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_874_Intake_3',
#   'name': 'Cardiovascular Surgery 874',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_875_Intake_1',
#   'name': 'Cardiovascular Surgery 875',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_876_Intake_9',
#   'name': 'Cardiovascular Surgery 876',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_877_Intake_3',
#   'name': 'Cardiovascular Surgery 877',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_878_Intake_2',
#   'name': 'Cardiovascular Surgery 878',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_879_Intake_6',
#   'name': 'Cardiovascular Surgery 879',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_880_Intake_2',
#   'name': 'Cardiovascular Surgery 880',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_881_Intake_9',
#   'name': 'Cardiovascular Surgery 881',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_882_Intake_5',
#   'name': 'Cardiovascular Surgery 882',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_883_Intake_5',
#   'name': 'Cardiovascular Surgery 883',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_884_Intake_4',
#   'name': 'Cardiovascular Surgery 884',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_885_Intake_7',
#   'name': 'Cardiovascular Surgery 885',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_886_Intake_8',
#   'name': 'Cardiovascular Surgery 886',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_887_Intake_7',
#   'name': 'Cardiovascular Surgery 887',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_888_Intake_4',
#   'name': 'Cardiovascular Surgery 888',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_889_Intake_10',
#   'name': 'Cardiovascular Surgery 889',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_890_Intake_3',
#   'name': 'Cardiovascular Surgery 890',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_891_Intake_7',
#   'name': 'Cardiovascular Surgery 891',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_892_Intake_10',
#   'name': 'Cardiovascular Surgery 892',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_893_Intake_8',
#   'name': 'Cardiovascular Surgery 893',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_894_Intake_8',
#   'name': 'Cardiovascular Surgery 894',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_895_Intake_5',
#   'name': 'Cardiovascular Surgery 895',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_896_Intake_3',
#   'name': 'Cardiovascular Surgery 896',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_897_Intake_6',
#   'name': 'Cardiovascular Surgery 897',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_898_Intake_1',
#   'name': 'Cardiovascular Surgery 898',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_899_Intake_9',
#   'name': 'Cardiovascular Surgery 899',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_900_Intake_1',
#   'name': 'Cardiovascular Surgery 900',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_901_Intake_2',
#   'name': 'Cardiovascular Surgery 901',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_902_Intake_6',
#   'name': 'Cardiovascular Surgery 902',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_903_Intake_8',
#   'name': 'Cardiovascular Surgery 903',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_904_Intake_4',
#   'name': 'Cardiovascular Surgery 904',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_905_Intake_1',
#   'name': 'Cardiovascular Surgery 905',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_906_Intake_7',
#   'name': 'Cardiovascular Surgery 906',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_907_Intake_9',
#   'name': 'Cardiovascular Surgery 907',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_908_Intake_5',
#   'name': 'Cardiovascular Surgery 908',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_909_Intake_10',
#   'name': 'Cardiovascular Surgery 909',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_910_Intake_2',
#   'name': 'Cardiovascular Surgery 910',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_911_Intake_3',
#   'name': 'Cardiovascular Surgery 911',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_912_Intake_2',
#   'name': 'Cardiovascular Surgery 912',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_913_Intake_5',
#   'name': 'Cardiovascular Surgery 913',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_914_Intake_2',
#   'name': 'Cardiovascular Surgery 914',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_915_Intake_2',
#   'name': 'Cardiovascular Surgery 915',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_916_Intake_7',
#   'name': 'Cardiovascular Surgery 916',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_917_Intake_10',
#   'name': 'Cardiovascular Surgery 917',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_918_Intake_1',
#   'name': 'Cardiovascular Surgery 918',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_919_Intake_7',
#   'name': 'Cardiovascular Surgery 919',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_920_Intake_7',
#   'name': 'Cardiovascular Surgery 920',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_921_Intake_8',
#   'name': 'Cardiovascular Surgery 921',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_922_Intake_6',
#   'name': 'Cardiovascular Surgery 922',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_923_Intake_5',
#   'name': 'Cardiovascular Surgery 923',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_924_Intake_5',
#   'name': 'Cardiovascular Surgery 924',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_925_Intake_9',
#   'name': 'Cardiovascular Surgery 925',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_926_Intake_7',
#   'name': 'Cardiovascular Surgery 926',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_927_Intake_7',
#   'name': 'Cardiovascular Surgery 927',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_928_Intake_8',
#   'name': 'Cardiovascular Surgery 928',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_929_Intake_4',
#   'name': 'Cardiovascular Surgery 929',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_930_Intake_5',
#   'name': 'Cardiovascular Surgery 930',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_931_Intake_7',
#   'name': 'Cardiovascular Surgery 931',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_932_Intake_2',
#   'name': 'Cardiovascular Surgery 932',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_933_Intake_1',
#   'name': 'Cardiovascular Surgery 933',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_934_Intake_5',
#   'name': 'Cardiovascular Surgery 934',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_935_Intake_6',
#   'name': 'Cardiovascular Surgery 935',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_936_Intake_6',
#   'name': 'Cardiovascular Surgery 936',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_937_Intake_3',
#   'name': 'Cardiovascular Surgery 937',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_938_Intake_10',
#   'name': 'Cardiovascular Surgery 938',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_939_Intake_9',
#   'name': 'Cardiovascular Surgery 939',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_940_Intake_9',
#   'name': 'Cardiovascular Surgery 940',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_941_Intake_1',
#   'name': 'Cardiovascular Surgery 941',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_942_Intake_3',
#   'name': 'Cardiovascular Surgery 942',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_943_Intake_2',
#   'name': 'Cardiovascular Surgery 943',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_944_Intake_9',
#   'name': 'Cardiovascular Surgery 944',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_945_Intake_1',
#   'name': 'Cardiovascular Surgery 945',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_946_Intake_3',
#   'name': 'Cardiovascular Surgery 946',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_947_Intake_8',
#   'name': 'Cardiovascular Surgery 947',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_948_Intake_5',
#   'name': 'Cardiovascular Surgery 948',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_949_Intake_5',
#   'name': 'Cardiovascular Surgery 949',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_950_Intake_4',
#   'name': 'Cardiovascular Surgery 950',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_951_Intake_6',
#   'name': 'Cardiovascular Surgery 951',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_952_Intake_1',
#   'name': 'Cardiovascular Surgery 952',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_953_Intake_9',
#   'name': 'Cardiovascular Surgery 953',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_954_Intake_10',
#   'name': 'Cardiovascular Surgery 954',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_955_Intake_3',
#   'name': 'Cardiovascular Surgery 955',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_956_Intake_1',
#   'name': 'Cardiovascular Surgery 956',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_957_Intake_9',
#   'name': 'Cardiovascular Surgery 957',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_958_Intake_5',
#   'name': 'Cardiovascular Surgery 958',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_959_Intake_9',
#   'name': 'Cardiovascular Surgery 959',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_960_Intake_8',
#   'name': 'Cardiovascular Surgery 960',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_961_Intake_10',
#   'name': 'Cardiovascular Surgery 961',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_962_Intake_6',
#   'name': 'Cardiovascular Surgery 962',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_963_Intake_3',
#   'name': 'Cardiovascular Surgery 963',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_964_Intake_8',
#   'name': 'Cardiovascular Surgery 964',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_965_Intake_8',
#   'name': 'Cardiovascular Surgery 965',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_966_Intake_3',
#   'name': 'Cardiovascular Surgery 966',
#   'type_id': 1,
#   'intake_date': 10},
#  {'id': 'Cardiovascular_Surgery_967_Intake_8',
#   'name': 'Cardiovascular Surgery 967',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_968_Intake_1',
#   'name': 'Cardiovascular Surgery 968',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_969_Intake_8',
#   'name': 'Cardiovascular Surgery 969',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_970_Intake_7',
#   'name': 'Cardiovascular Surgery 970',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_971_Intake_3',
#   'name': 'Cardiovascular Surgery 971',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_972_Intake_3',
#   'name': 'Cardiovascular Surgery 972',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_973_Intake_7',
#   'name': 'Cardiovascular Surgery 973',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_974_Intake_8',
#   'name': 'Cardiovascular Surgery 974',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_975_Intake_8',
#   'name': 'Cardiovascular Surgery 975',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_976_Intake_6',
#   'name': 'Cardiovascular Surgery 976',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_977_Intake_9',
#   'name': 'Cardiovascular Surgery 977',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_978_Intake_10',
#   'name': 'Cardiovascular Surgery 978',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_979_Intake_4',
#   'name': 'Cardiovascular Surgery 979',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_980_Intake_6',
#   'name': 'Cardiovascular Surgery 980',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_981_Intake_6',
#   'name': 'Cardiovascular Surgery 981',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_982_Intake_7',
#   'name': 'Cardiovascular Surgery 982',
#   'type_id': 1,
#   'intake_date': 1},
#  {'id': 'Cardiovascular_Surgery_983_Intake_5',
#   'name': 'Cardiovascular Surgery 983',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_984_Intake_5',
#   'name': 'Cardiovascular Surgery 984',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_985_Intake_4',
#   'name': 'Cardiovascular Surgery 985',
#   'type_id': 1,
#   'intake_date': 3},
#  {'id': 'Cardiovascular_Surgery_986_Intake_7',
#   'name': 'Cardiovascular Surgery 986',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_987_Intake_8',
#   'name': 'Cardiovascular Surgery 987',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_988_Intake_6',
#   'name': 'Cardiovascular Surgery 988',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_989_Intake_4',
#   'name': 'Cardiovascular Surgery 989',
#   'type_id': 1,
#   'intake_date': 2},
#  {'id': 'Cardiovascular_Surgery_990_Intake_9',
#   'name': 'Cardiovascular Surgery 990',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_991_Intake_4',
#   'name': 'Cardiovascular Surgery 991',
#   'type_id': 1,
#   'intake_date': 8},
#  {'id': 'Cardiovascular_Surgery_992_Intake_7',
#   'name': 'Cardiovascular Surgery 992',
#   'type_id': 1,
#   'intake_date': 7},
#  {'id': 'Cardiovascular_Surgery_993_Intake_9',
#   'name': 'Cardiovascular Surgery 993',
#   'type_id': 1,
#   'intake_date': 9},
#  {'id': 'Cardiovascular_Surgery_994_Intake_8',
#   'name': 'Cardiovascular Surgery 994',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_995_Intake_1',
#   'name': 'Cardiovascular Surgery 995',
#   'type_id': 1,
#   'intake_date': 5},
#  {'id': 'Cardiovascular_Surgery_996_Intake_3',
#   'name': 'Cardiovascular Surgery 996',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_997_Intake_6',
#   'name': 'Cardiovascular Surgery 997',
#   'type_id': 1,
#   'intake_date': 6},
#  {'id': 'Cardiovascular_Surgery_998_Intake_1',
#   'name': 'Cardiovascular Surgery 998',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_999_Intake_7',
#   'name': 'Cardiovascular Surgery 999',
#   'type_id': 1,
#   'intake_date': 4},
#  {'id': 'Cardiovascular_Surgery_1000_Intake_7',
#   'name': 'Cardiovascular Surgery 1000',
#   'type_id': 1,
#   'intake_date': 9},
#  ...]

# %%
from gurobipy import Model, GRB
import numpy as np

def schedule_surgeries_rolling(surgeries, surgery_type_attributes, day_capacities, beta=0.5):
    """
    Schedule surgeries within a rolling horizon optimization framework, assuming one room per day.
    
    Parameters:
    - surgeries: List of dictionaries representing surgeries with 'id', 'type_id', and 'intake_date'.
    - surgery_type_attributes: Dictionary mapping surgery types to their attributes (duration, variance, priority).
    - day_capacities: Dictionary with days as keys and available hours as values for the single room available that day.
    - beta: Multiplier for variance-based slack time adjustment.
    
    Returns:
    - scheduled_surgeries: Dictionary with scheduled day for each surgery. Room is omitted since there's only one per day.
    - updated_day_capacities: Updated day capacities after scheduling surgeries.
    """
    
    m = Model("SurgeryScheduling")

    # Define decision variables for surgeries scheduled on each day
    surgery_scheduled = m.addVars(
        [(surgery['id'], d) for surgery in surgeries for d in day_capacities.keys()], 
        vtype=GRB.BINARY, 
        name="schedule"
    )

    # Ensure that surgery_type_attributes includes entries for all possible type_id values
    type_ids = set(surgery['type_id'] for surgery in surgeries)
    for type_id in type_ids:
        if type_id not in surgery_type_attributes:
            surgery_type_attributes[type_id] = {
                'duration': 1,  # Placeholder value for duration
                'variance': 0,  # Placeholder value for variance
                'priority': 1   # Placeholder value for priority
            }

    # Define the objective function
    m.setObjective(
        sum(
            surgery_scheduled[surgery['id'], d] * 
            surgery_type_attributes[surgery['type_id']]['priority'] * 
            beta*(max(day_capacities.keys()) - d + surgery['intake_date'])  # Example weight calculation, assumes days are numeric
            for surgery in surgeries for d in day_capacities.keys()
        ),
        GRB.MAXIMIZE
    )

    # Add constraints
    # Each surgery can only be scheduled once
    for surgery in surgeries:
        m.addConstr(
            sum(surgery_scheduled[surgery['id'], d] for d in day_capacities.keys()) <= 1,
            f"OneTime_{surgery['id']}"
        )

    # Respect the available hours for the single room each day
    for d in day_capacities.keys():
        m.addConstr(
            sum(surgery_scheduled[surgery['id'], d] * surgery_type_attributes[surgery['type_id']]['duration'] for surgery in surgeries) <= day_capacities[d],
            f"RoomAvailability_{d}"
        )

    # Optimize the model
    m.optimize()

    # Extract the scheduling results
    scheduled_surgeries = {
        surgery['id']: {"day": d}
        for surgery in surgeries for d in day_capacities.keys()
        if surgery_scheduled[surgery['id'], d].X > 0.5
    }

    # Update day capacities based on scheduled surgeries
    updated_day_capacities = day_capacities.copy()
    for surgery_id, info in scheduled_surgeries.items():
        updated_day_capacities[info['day']] -= surgery_type_attributes[surgeries[0]['type_id']]['duration']  # Assuming all surgeries have the same duration
    
    return scheduled_surgeries, updated_day_capacities


# Example usage:

# Set the capacity for each day to 24 hours
day_capacities = {day: 24 for day in range(1, num_days + 1)}

# Now, call the function with the extended surgeries list and other parameters
scheduled_surgeries, updated_day_capacities = schedule_surgeries_rolling(
    extended_surgeries, 
    surgery_type_attributes,
    day_capacities
)

# Print the scheduled surgeries for each day
for surgery_id, info in scheduled_surgeries.items():
    print(f"Surgery {surgery_id} scheduled on day {info['day']}")

# Print the updated day capacities
print("Updated day capacities:")
for day, capacity in updated_day_capacities.items():
    print(f"Day {day}: {capacity} hours")
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1355U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# Cell In[10], line 88
#      85 day_capacities = {day: 24 for day in range(1, num_days + 1)}
#      87 # Now, call the function with the extended surgeries list and other parameters
# ---> 88 scheduled_surgeries, updated_day_capacities = schedule_surgeries_rolling(
#      89     extended_surgeries,
#      90     surgery_type_attributes,
#      91     day_capacities
#      92 )
#      94 # Print the scheduled surgeries for each day
#      95 for surgery_id, info in scheduled_surgeries.items():
#
# Cell In[10], line 65, in schedule_surgeries_rolling(surgeries, surgery_type_attributes, day_capacities, beta)
#      59     m.addConstr(
#      60         sum(surgery_scheduled[surgery['id'], d] * surgery_type_attributes[surgery['type_id']]['duration'] for surgery in surgeries) <= day_capacities[d],
#      61         f"RoomAvailability_{d}"
#      62     )
#      64 # Optimize the model
# ---> 65 m.optimize()
#      67 # Extract the scheduling results
#      68 scheduled_surgeries = {
#      69     surgery['id']: {"day": d}
#      70     for surgery in surgeries for d in day_capacities.keys()
#      71     if surgery_scheduled[surgery['id'], d].X > 0.5
#      72 }
#
# File src\\gurobipy\\model.pxi:893, in gurobipy.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information

# %%
from gurobipy import Model, GRB
import numpy as np

hours_per_day = 24  # Assume 3 rooms of 8hrs each
beta = 0.0  # Initial beta value for slack time adjustment

# Define the number of days in your planning horizon
num_days = 30

# Set the capacity for each day to 24 hours
day_capacities = {day: 24 for day in range(1, num_days + 1)}

# Now, call the function with the extended surgeries list and other parameters
scheduled_surgeries = schedule_surgeries_rolling(
    extended_surgeries, 
    surgery_type_attributes,
    day_capacities
)

# Since the direct output might be extensive, let's summarize the results
# Counting the number of scheduled surgeries per day and room
scheduled_summary = {}
# Create a list to hold details of scheduled surgeries
scheduled_surgeries_list = []

# Set the capacity for each day to 24 hours
day_capacities = {day: 24 for day in range(1, num_days + 1)}

# Now, call the function with the extended surgeries list and other parameters
scheduled_surgeries, updated_day_capacities = schedule_surgeries_rolling(
    extended_surgeries, 
    surgery_type_attributes,
    day_capacities
)

# Print the scheduled surgeries for each day
for surgery_id, info in scheduled_surgeries.items():
    print(f"Surgery {surgery_id} scheduled on day {info['day']}")

# Print the updated day capacities
print("Updated day capacities:")
for day, capacity in updated_day_capacities.items():
    print(f"Day {day}: {capacity} hours")
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1355U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 35 rows, 150 columns and 300 nonzeros
# Model fingerprint: 0xe930280e
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e-01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 80.5000000
# Presolve removed 35 rows and 150 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 80.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+01, best bound 8.050000000000e+01, gap 0.0000%
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1355U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 35 rows, 150 columns and 300 nonzeros
# Model fingerprint: 0xe930280e
# Variable types: 0 continuous, 150 integer (150 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [5e-01, 2e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective 80.5000000
# Presolve removed 35 rows and 150 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 80.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.050000000000e+01, best bound 8.050000000000e+01, gap 0.0000%
# Surgery Cardiovascular_Surgery_1_Intake_6 scheduled on day 1
# Surgery Neurological_Surgery_1_Intake_6 scheduled on day 1
# Surgery Orthopedic_Surgery_1_Intake_5 scheduled on day 1
# Surgery Gastrointestinal_Surgery_1_Intake_6 scheduled on day 1
# Surgery Cosmetic_Surgery_1_Intake_9 scheduled on day 1
# Updated day capacities:
# Day 1: 19 hours
# Day 2: 24 hours
# Day 3: 24 hours
# Day 4: 24 hours
# Day 5: 24 hours
# Day 6: 24 hours
# Day 7: 24 hours
# Day 8: 24 hours
# Day 9: 24 hours
# Day 10: 24 hours
# Day 11: 24 hours
# Day 12: 24 hours
# Day 13: 24 hours
# Day 14: 24 hours
# Day 15: 24 hours
# Day 16: 24 hours
# Day 17: 24 hours
# Day 18: 24 hours
# Day 19: 24 hours
# Day 20: 24 hours
# Day 21: 24 hours
# Day 22: 24 hours
# Day 23: 24 hours
# Day 24: 24 hours
# Day 25: 24 hours
# Day 26: 24 hours
# Day 27: 24 hours
# Day 28: 24 hours
# Day 29: 24 hours
# Day 30: 24 hours
